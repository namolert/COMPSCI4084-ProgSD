# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Task 1

# %%
x = np.arange(1, 31)
y = x * 2
plt.figure(figsize=(6, 3))
plt.plot(x, y)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Task 1")
plt.show()

# %% [markdown]
# Task 2

# %%
# Wait for fdata.csv

# %% [markdown]
# Task 3

# %%
x = np.arange(1, 31)
y1 = x * 2
y2 = np.sin(np.pi + x) * 30 + 30
plt.figure(figsize=(6, 3))
plt.plot(x, y1, linewidth=5, color='r', linestyle='--')
plt.plot(x, y2, linewidth=2, color='g', linestyle=':')
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Task 3")
plt.legend(['straight', 'sin'])
plt.show()

# %% [markdown]
# Task 4

# %%
ry1 = np.linspace(20, 40, 5)
ry2 = np.linspace(40, 10, 5)
ry = np.hstack((ry1, ry2[1:]))
print(ry)

gy1 = np.linspace(40, 10, 5)
gy2 = np.linspace(10, 30, 5)
gy = np.hstack((gy1, gy2[1:]))
print(gy)
# Out:
# [20.  25.  30.  35.  40.  32.5 25.  17.5 10. ]
# [40.  32.5 25.  17.5 10.  15.  20.  25.  30. ]

# %%
x = np.linspace(10, 30, 9)
plt.figure(figsize=(6, 3))
plt.plot(x, ry, linewidth=2, color='r', linestyle=':')
plt.plot(x, gy, linewidth=4, color='g', linestyle='--')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Plot with two or more lines with different styles")
plt.legend(['red-dotted', 'green-dashed'], loc=1)
plt.show()

# %% [markdown]
# Task 5

# %%
x1 = [20, 30, 50, 60, 80]
y1 = [10, 50, 100, 180, 200]
x2 = [30, 40, 60, 70, 90]
y2 = [20, 60, 110, 200, 220]
plt.figure(figsize=(6, 3))
plt.plot(x1, y1, linewidth=2, color='r', linestyle=':')
plt.plot(x2, y2, linewidth=2, color='g', linestyle='--')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Quantities")
plt.legend(['1', '2'], loc=4)
plt.show()

# %% [markdown]
# Task 6

# %%
x = np.arange(0, 5, 0.1)
y1 = np.sin(2 * np.pi * x)
y2 = np.cos(2 * np.pi * x)
y3 = np.tan(2 * np.pi * x)
plt.subplot(311)
plt.plot(x, y1, linestyle='-.', color='r')
plt.subplot(312)
plt.plot(x, y2, linestyle='--', color='g')
plt.subplot(313)
plt.plot(x, y3, linestyle=':', color='b')
plt.show()

# %% [markdown]
# Task 7

# %%
index = ['Python', 'Java', 'C', 'C++', 'R', 'Javascript', 'C#']
values = [100, 96.3, 94.4, 87.5, 81.5, 79.4, 74.5]
plt.figure(figsize=(6, 4))
plt.bar(index, values)
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.title("Popularity of Programming")
plt.show()

# %% [markdown]
# Task 8

# %%
plt.figure(figsize=(6, 4))
plt.barh(index, values)
plt.ylabel("Programming Languages")
plt.xlabel("Popularity")
plt.title("Popularity of Programming")
plt.show()

# %% [markdown]
# Task 9

# %%
colors = ['red', 'green', 'blue', 'yellow', 'orange', 'gray', 'purple']
plt.figure(figsize=(6, 4))
plt.bar(index, values, color=colors)
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.title("Popularity of Programming")
plt.show()

# %% [markdown]
# Task 10

# %%
colors = ['red', 'green', 'blue', 'yellow', 'orange', 'gray', 'purple']
plt.figure(figsize=(6, 4))
plt.bar(index, values, color=colors)
for x, y in zip(index, values):
    plt.text(x, y, '%.2f'%y, ha='center')
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.title("Popularity of Programming")
plt.show()

# %% [markdown]
# Task 11

# %%
plt.figure(figsize=(6, 4))
plt.pie(values, labels=index, autopct='%.2f%%')
plt.title("Popularity of Programming")
plt.show()

# %% [markdown]
# Task 12

# %%
explode = [0.3, 0.1, 0.1, 0, 0, 0, 0]
plt.figure(figsize=(6, 4))
plt.pie(values, labels=index, autopct='%.2f%%', explode=explode, startangle=45)
plt.title("Popularity of Programming")
plt.show()

# %% [markdown]
# Task 13

# %%
data = {
    'a': [10, 80, 80, 70, 25],
    'b': [40, 38, 36, 45, 45],
    'c': [39, 24, 90, 30, 39],
    'd': [30, 33, 25, 69, 30],
    'e': [39, 50, 44, 15, 55],
}
df = pd.DataFrame(data)
df
# Out:
#     a   b   c   d   e
# 0  10  40  39  30  39
# 1  80  38  24  33  50
# 2  80  36  90  25  44
# 3  70  45  30  69  15
# 4  25  45  39  30  55

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Task 14

# %%
index2 = ['a', 'b', 'c', 'd']
values2 = [0.2474, 0.1235, 0.1737, 0.1824]
std = [0.3314, 0.2278, 0.2836, 0.2645]
plt.figure(figsize=(6, 4))
plt.bar(index2, values2, yerr=std, error_kw={'ecolor':'0.1', 'capsize':6})
plt.xlabel("Sample Data")
plt.ylabel("Mean Velocity")
plt.title("")
plt.show()

# %% [markdown]
# Task 15

# %%
g_index = ['a', 'b', 'c', 'd', 'e']
m_means = [22, 30, 35, 35, 26]
w_means = [25, 32, 30, 35, 29]
m_std = [4, 3, 4, 1, 5]
w_std = [3, 5, 2, 3, 3]
g_data = {'Men': m_means, 'Women': w_means}
g_df = pd.DataFrame(g_data)
g_df.plot(kind='bar', stacked=True, yerr=[m_std, w_std], error_kw={'ecolor':'0.1', 'capsize':6})
# Out:
# <Axes: >

# %%
p = np.random.randint(0, 100, 100)
p
# Out:
# array([43,  6, 72, 77, 74, 53, 44,  4, 45,  9, 36, 13, 46, 46, 36, 13, 85,
#        15, 57, 92, 59, 28, 53, 58, 41, 41,  8, 59, 63,  5, 74, 92, 55, 95,
#        66, 25, 36, 74, 46, 34, 22, 15, 48,  3, 24, 84, 62, 27, 86, 38, 22,
#        20, 13, 56, 35, 31, 66, 29, 94, 99, 82, 90, 54, 71, 24, 42, 88, 49,
#        12, 88,  2, 81, 82, 52, 55,  6, 70, 67, 40, 99, 63, 57, 67, 68, 45,
#        22, 86, 66, 60, 25, 55, 22, 63, 95, 60, 29, 18, 49,  8, 23])

# %%
plt.hist(p, bins=20)
plt.show()

# %%
da = {
    "s1": [1, 2, 4, 5],
    "s2": [4, 4, 55, 6]
}

df = pd.DataFrame(da)
df['s1'].plot(kind='pie')
# Out:
# <Axes: ylabel='s1'>
